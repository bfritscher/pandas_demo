# %%
import seaborn as sns
from scipy.optimize import curve_fit
# Function for linear fit
def func(x, a, b):
    return a + b * x

# %%
# source https://github.com/thomas-haslwanter/statsintro_python/tree/master/ISP/Code_Quantlets/11_LinearModels/anscombe
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", size=4,
           scatter_kws={"s": 50, "alpha": 1});

# %%
df.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
linreg = LinearRegression()

# %%
def r(e):
    (popt, pcov) = curve_fit(func, e.x, e.y)
    return 'Linear regression coefficients: y = {a:.2f} + {b:.2f}x'.format(a=popt[0], b=popt[1])

# %%
df.groupby('dataset').apply(r)
# Out:
# dataset
# I      Linear regression coefficients: y = 3.00 + 0.50x
# II     Linear regression coefficients: y = 3.00 + 0.50x
# III    Linear regression coefficients: y = 3.00 + 0.50x
# IV     Linear regression coefficients: y = 3.00 + 0.50x
# dtype: object
